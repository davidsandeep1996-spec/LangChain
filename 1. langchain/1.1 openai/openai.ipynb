# %%
# Text Loader

from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader('chat.txt')

loader.load()
# Out:
# [Document(metadata={'source': 'chat.txt'}, page_content='Ahh! £20? 🔥 That’s a steal if the bike is basically rideable. Let’s break this down carefully before you hand over cash:\n💷 Value Check\nFor £20 you are well below market price. Even bikes in poor condition often sell £40–80.\nEven if you spend £40–60 on service + a new saddle, total is ~£60–80 → still excellent value for a commuter/grocery bike.\n✅ Why It’s a Good Deal\nFrame + wheels alone are worth more than £20.\nTyres & brakes are said to be good (normally that alone saves you ~£30–40).\nNew grips already fitted (tiny upgrade, but shows some care).\nYou already spotted the only obvious flaw: saddle hole.\n⚠️ What to Double-Check in Person\nSince the bike is resprayed & cheap, do a quick inspection before saying yes:\nFrame – Look around joints (bottom bracket, seat tube, head tube) for cracks. A respray can hide issues.\nWheels – Spin them; do they wobble side-to-side? If badly bent, costly to fix.\nBrakes – Squeeze hard. 
# ...

# %%
! pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 27.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

pypdf_load= PyPDFLoader('task2-data-description.pdf')
pypdf_load=pypdf_load.load()

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader=WebBaseLoader(web_path="https://www.linkedin.com/pulse/100-top-artificial-intelligence-ai-companies-2023-george-oliveira",
                     bs_kwargs=dict(parse_only=bs4.SoupStrainer(
                         class_=("font-[700]")
                         
                     )))

# %%
loader.load()
# Out:
# [Document(metadata={'source': 'https://www.linkedin.com/pulse/100-top-artificial-intelligence-ai-companies-2023-george-oliveira'}, page_content='Cloud AI Companies1. Google Cloud2. IBM Cloud3. Alibaba Cloud4. Amazon Web Services (AWS)5. DataRobot6. Baidu AI Cloud7. Microsoft Azure8. SalesforceHealthcare AI Companies9. Tempus10. Suki.Ai11. Nanox12. Freenome13. Neurala14. ICarbonX15. Flatiron Health16. Deep 617. Butterfly Network18. K Health19. InsitroVehicle/Transportation AI Companies20. Anduril Industries21. AEye22. Pony.Ai23. Nauto24. Nuro25. Zoox26. DJI27. Orbital InsightSecurity AI Companies28. CrowdStrike29. BlackBerry30. DataVisor31. Sherpa.Ai32. BigPanda33. Symphony AyasdiAI34. Dataminr35. DarktraceE-Commerce AI Companies36. Algorithmia37. The Trade Desk38. Swim.Ai39. Phrasee40. Pymetrics41. People.Ai42. AlphaSense43. Icertis44. Bizzabo45. One Model46. CopyAI47. C3.Ai48. Accubits49. SS&C Blue Prism50. DocuSign51. Tetra Tech52. Nvidia53. ViSenze54. ServiceNow55. Pointr56. Direc
# ...

# %%
from langchain_community.document_loaders import ArxivLoader

docs=ArxivLoader(query="2508.19151", load_max_docs=2).load()

# %%
docs
# Out:
# [Document(metadata={'Published': '2025-08-26', 'Title': 'Saddle Hierarchy in Dense Associative Memory', 'Authors': 'Robin Thériault, Daniele Tantari', 'Summary': 'Dense associative memory (DAM) models have been attracting renewed attention\nsince they were shown to be robust to adversarial examples and closely related\nto state-of-the-art machine learning paradigms, such as the attention\nmechanisms in transformers and generative diffusion models. We study a DAM\nbuilt upon a three-layer Boltzmann machine with Potts hidden units, which\nrepresent data clusters and classes. Through a statistical mechanics analysis,\nwe derive saddle-point equations that characterize both the stationary points\nof DAMs trained on real data and the fixed points of DAMs trained on synthetic\ndata within a teacher-student framework. Based on these results, we propose a\nnovel regularization scheme that makes training significantly more stable.\nMoreover, we show empirically that our DAM learns interpretab
# ...

# %%
! pip install langchain_openai
# Out:
# ...
#   Using cached openai-1.102.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached jiter-0.10.0-cp39-cp39-macosx_10_12_x86_64.whl.metadata (5.2 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached openai-1.102.0-py3-none-any.whl (812 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.10.0-cp39-cp39-macosx_10_12_x86_64.whl (317 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.8 MB/s eta 0:00:00
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain_openai][langchain_openai]
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=10)

text_splitter.split_documents(pypdf_load)
# Out:
# [Document(metadata={'producer': 'macOS Version 10.15.6 (Build 19G73) Quartz PDFContext', 'creator': 'PyPDF', 'creationdate': "D:20200924032210Z00'00'", 'moddate': "D:20200924032210Z00'00'", 'source': 'task2-data-description.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='0\nCopyright © 2020 by Boston Consulting Group. All rights reserved.\nPowerCocase task description'),
#  Document(metadata={'producer': 'macOS Version 10.15.6 (Build 19G73) Quartz PDFContext', 'creator': 'PyPDF', 'creationdate': "D:20200924032210Z00'00'", 'moddate': "D:20200924032210Z00'00'", 'source': 'task2-data-description.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content="We have scheduled a meeting in one week's time with the head of the SME division in which you will"),
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ['OPEN_API_KEY']=os.getenv('OPEN_API_KEY')

# %%
from langchain_openai import OpenAIEmbeddings
